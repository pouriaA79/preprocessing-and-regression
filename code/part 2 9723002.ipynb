# %%
import pandas as pd

# %%
players =pd.read_csv('players.csv')

# %%
players.head()
# Out:
#        ID               Name                      FullName  Age  Height  \
# 0  158023           L. Messi                  Lionel Messi   33     170
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro   35     187
# 2  200389           J. Oblak                     Jan Oblak   27     188
# 3  192985       K. De Bruyne               Kevin De Bruyne   29     181
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.   28     175
#
#    Weight                                          PhotoUrl Nationality  \
# 0      72  https://cdn.sofifa.com/players/158/023/21_60.png   Argentina
# 1      83  https://cdn.sofifa.com/players/020/801/21_60.png    Portugal
# 2      87  https://cdn.sofifa.com/players/200/389/21_60.png    Slovenia
# 3      70  https://cdn.sofifa.com/players/192/985/21_60.png     Belgium
# 4      68  https://cdn.sofifa.com/players/190/871/21_60.png      Brazil
#
#    Overall  Potential  ...  LMRating  CMRating  RMRating LWBRating CDMRating  \
# 0       93         93  ...        93        90        93        69        68
# 1       92         92  ...        91        84        91        68        64
# 2       91         93  ...        38        41        38        35        39
# 3       91         91  ...        91        91        91        82        83
# 4       91         91  ...        91        86        91        70        65
#
#   RWBRating  LBRating  CBRating  RBRating GKRating
# 0        69        65        55        65       22
# 1        68        64        57        64       23
# 2        35        35        36        35       92
# 3        82        78        72        78       24
# 4        70        65        52        65       23
#
# [5 rows x 90 columns]

# %%
players.tail()
# Out:
#            ID           Name           FullName  Age  Height  Weight  \
# 19015  257371    M. Nzongong      Mike Nzongong   19     179      74
# 19016  259160        L. Bell         Lewis Bell   17     181      70
# 19017  259157        Y. Arai         Yasin Arai   16     176      70
# 19018  253763     R. Dinanga    Ricardo Dinanga   18     174      73
# 19019  241493  S. Cartwright  Samuel Cartwright   19     185      75
#
#                                                PhotoUrl          Nationality  \
# 19015  https://cdn.sofifa.com/players/257/371/21_60.png  Republic of Ireland
# 19016  https://cdn.sofifa.com/players/259/160/21_60.png              England
# 19017  https://cdn.sofifa.com/players/259/157/21_60.png              England
# 19018  https://cdn.sofifa.com/players/253/763/21_60.png  Republic of Ireland
# 19019  https://cdn.sofifa.com/players/241/493/21_60.png              England
#
#        Overall  Potential  ...  LMRating  CMRating  RMRating LWBRating  \
# 19015       49         60  ...        51        47        51        44
# 19016       49         67  ...        51        44        51        42
# 19017       49         74  ...        53        47        53        45
# 19018       49         59  ...        49        43        49        36
# 19019       49         65  ...        38        36        38        46
#
#       CDMRating RWBRating  LBRating  CBRating  RBRating GKRating
# 19015        42        44        42        40        42       18
# 19016        38        42        41        35        41       13
# 19017        40        45        44        39        44       17
# 19018        32        36        34        30        34       16
# 19019        45        46        47        51        47       15
#
# [5 rows x 90 columns]

# %% [markdown]
# ## without library

# %%
## first 10 players
players.iloc[:10 , :]
# Out:
#        ID               Name                      FullName  Age  Height  \
# 0  158023           L. Messi                  Lionel Messi   33     170
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro   35     187
# 2  200389           J. Oblak                     Jan Oblak   27     188
# 3  192985       K. De Bruyne               Kevin De Bruyne   29     181
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.   28     175
# 5  188545     R. Lewandowski            Robert Lewandowski   31     184
# 6  208722            S. Mané                    Sadio Mané   28     175
# 7  192448      M. ter Stegen         Marc-André ter Stegen   28     187
# 8  203376        V. van Dijk               Virgil van Dijk   28     193
# 9  167495           M. Neuer                  Manuel Neuer   34     193
#
#    Weight                                          PhotoUrl  Nationality  \
# 0      72  https://cdn.sofifa.com/players/158/023/21_60.png    Argentina
# 1      83  https://cdn.sofifa.com/players/020/801/21_60.png     Portugal
# 2      87  https://cdn.sofifa.com/players/200/389/21_60.png     Slovenia
# 3      70  https://cdn.sofifa.com/players/192/985/21_60.png      Belgium
# 4      68  https://cdn.sofifa.com/players/190/871/21_60.png       Brazil
# 5      80  https://cdn.sofifa.com/players/188/545/21_60.png       Poland
# 6      69  https://cdn.sofifa.com/players/208/722/21_60.png      Senegal
# 7      85  https://cdn.sofifa.com/players/192/448/21_60.png      Germany
# 8      92  https://cdn.sofifa.com/players/203/376/21_60.png  Netherlands
# 9      92  https://cdn.sofifa.com/players/167/495/21_60.png      Germany
#
#    Overall  Potential  ...  LMRating  CMRating  RMRating LWBRating CDMRating  \
# 0       93         93  ...        93        90        93        69        68
# 1       92         92  ...        91        84        91        68        64
# 2       91         93  ...        38        41        38        35        39
# 3       91         91  ...        91        91        91        82        83
# 4       91         91  ...        91        86        91        70        65
# 5       91         91  ...        86        83        86        67        69
# 6       90         90  ...        90        84        90        72        68
# 7       90         93  ...        42        48        42        36        44
# 8       90         91  ...        73        79        73        83        88
# 9       90         90  ...        47        53        47        39        46
#
#   RWBRating  LBRating  CBRating  RBRating GKRating
# 0        69        65        55        65       22
# 1        68        64        57        64       23
# 2        35        35        36        35       92
# 3        82        78        72        78       24
# 4        70        65        52        65       23
# 5        67        64        63        64       22
# 6        72        69        62        69       23
# 7        36        34        36        34       91
# 8        83        85        91        85       23
# 9        39        38        37        38       90
#
# [10 rows x 90 columns]

# %%
## last ten players
players.iloc[-10: , :]
# Out:
#            ID           Name           FullName  Age  Height  Weight  \
# 19010  259381      W. Delvin     Willads Delvin   19     165      55
# 19011  248379     S. Doherty    Stephen Doherty   20     176      77
# 19012  255547    Cha Oh Yeon        Oh Yeon Cha   22     186      77
# 19013  255549  Kang Sang Hee      Sang Hee Kang   22     180      73
# 19014  257116     C. Diabate     Cheick Diabate   19     192      78
# 19015  257371    M. Nzongong      Mike Nzongong   19     179      74
# 19016  259160        L. Bell         Lewis Bell   17     181      70
# 19017  259157        Y. Arai         Yasin Arai   16     176      70
# 19018  253763     R. Dinanga    Ricardo Dinanga   18     174      73
# 19019  241493  S. Cartwright  Samuel Cartwright   19     185      75
#
#                                                PhotoUrl          Nationality  \
# 19010  https://cdn.sofifa.com/players/259/381/21_60.png              Denmark
# 19011  https://cdn.sofifa.com/players/248/379/21_60.png  Republic of Ireland
# 19012  https://cdn.sofifa.com/players/255/547/21_60.png       Korea Republic
# 19013  https://cdn.sofifa.com/players/255/549/21_60.png       Korea Republic
# 19014  https://cdn.sofifa.com/players/257/116/21_60.png              England
# 19015  https://cdn.sofifa.com/players/257/371/21_60.png  Republic of Ireland
# 19016  https://cdn.sofifa.com/players/259/160/21_60.png              England
# 19017  https://cdn.sofifa.com/players/259/157/21_60.png              England
# 19018  https://cdn.sofifa.com/players/253/763/21_60.png  Republic of Ireland
# 19019  https://cdn.sofifa.com/players/241/493/21_60.png              England
#
#        Overall  Potential  ...  LMRating  CMRating  RMRating LWBRating  \
# 19010       49         62  ...        50        44        50        38
# 19011       49         59  ...        51        48        51        45
# 19012       49         60  ...        49        51        49        52
# 19013       49         61  ...        36        35        36        47
# 19014       49         60  ...        42        41        42        48
# 19015       49         60  ...        51        47        51        44
# 19016       49         67  ...        51        44        51        42
# 19017       49         74  ...        53        47        53        45
# 19018       49         59  ...        49        43        49        36
# 19019       49         65  ...        38        36        38        46
#
#       CDMRating RWBRating  LBRating  CBRating  RBRating GKRating
# 19010        35        38        36        31        36       13
# 19011        42        45        44        39        44       17
# 19012        54        52        53        56        53       18
# 19013        45        47        50        51        50       16
# 19014        47        48        49        51        49       17
# 19015        42        44        42        40        42       18
# 19016        38        42        41        35        41       13
# 19017        40        45        44        39        44       17
# 19018        32        36        34        30        34       16
# 19019        45        46        47        51        47       15
#
# [10 rows x 90 columns]

# %% [markdown]
# ## missing values

# %%
count_missing_value = players.isnull().sum()

# %%
for i in range(players.shape[1]):
    if count_missing_value[i]>0:
        print ("{} column has {} missing valus".format(list(players.columns)[i],count_missing_value[i]))
# Out:
# ClubPosition column has 234 missing valus
# ContractUntil column has 234 missing valus
# ClubNumber column has 234 missing valus
# NationalPosition column has 17895 missing valus
# NationalNumber column has 17895 missing valus

# %% [markdown]
# ## weight min max avg

# %%
players['Weight'].describe()
# Out:
# count    19020.000000
# mean        75.052419
# std          7.058038
# min         50.000000
# 25%         70.000000
# 50%         75.000000
# 75%         80.000000
# max        110.000000
# Name: Weight, dtype: float64

# %%
##second approach

# %%
W_min = 0
W_max = 0
W_sum = 0
for i  in range (players.shape[0]):
    if i ==0:
        W_min = players.iloc[i]['Weight']
        W_max = W_min
        W_sum += W_min
    else:
        weightt = players.iloc[i]['Weight']
        if W_min > weightt:
            W_min = weightt
        elif W_max < weightt :
            W_max = weightt
        W_sum += weightt

print("MInimum weight is {}".format(W_min))
print("Maximum weight is {}".format(W_max))
print("average weight is {}".format(W_sum/players.shape[0]))
# Out:
# MInimum weight is 50
# Maximum weight is 110
# average weight is 75.05241850683491

# %% [markdown]
# ## most and least players

# %%
players['Nationality'].value_counts().head(1)
# Out:
# England    1706
# Name: Nationality, dtype: int64

# %%
players['Nationality'].value_counts().tail(23)
# Out:
# Tanzania               1
# Rwanda                 1
# Papua New Guinea       1
# Saint Lucia            1
# New Caledonia          1
# Singapore              1
# Guam                   1
# Barbados               1
# Suriname               1
# Indonesia              1
# Malaysia               1
# Guatemala              1
# Puerto Rico            1
# Hong Kong              1
# Bermuda                1
# Malta                  1
# Korea DPR              1
# Andorra                1
# Aruba                  1
# Malawi                 1
# São Tomé & Príncipe    1
# Chad                   1
# South Sudan            1
# Name: Nationality, dtype: int64

# %%
## second approach

# %%
nationality_dict = {}
zz= players['Nationality'].unique()
for i in range (len(zz)):
        nationality_dict[zz[i]] = 0
for i  in range (players.shape[0]):
     nationality_dict[players.iloc[i]['Nationality']] +=1

# %%
all_values = nationality_dict.values()
max_value = max(all_values)
min_value = min(all_values)
min_list = []
max_list = []
for i in range(len(nationality_dict)):
    if nationality_dict[zz[i]] == min_value:
        min_list.append(zz[i])
    elif nationality_dict[zz[i]] == max_value:
        max_list.append(zz[i])
        
print("Maximum numbers of players is for {} with {} players".format(max_list,max_value))

print("Minimum numbers of players is for {} with {} players".format(min_list,min_value))
# Out:
# Maximum numbers of players is for ['England'] with 1706 players
# Minimum numbers of players is for ['Tanzania', 'Chad', 'Bermuda', 'Puerto Rico', 'New Caledonia', 'São Tomé & Príncipe', 'Malawi', 'Aruba', 'Suriname', 'Guam', 'Rwanda', 'Andorra', 'Papua New Guinea', 'Saint Lucia', 'Korea DPR', 'Malta', 'Guatemala', 'Barbados', 'South Sudan', 'Singapore', 'Hong Kong', 'Indonesia', 'Malaysia'] with 1 players

# %% [markdown]
# ## Growth < 3 and potential < 84

# %%
players_list = []
player_new1=players[players['Growth']<3]
player_new=player_new1[player_new1['Potential']<84]

for i  in range (player_new.shape[0]):
    players_list.append(player_new.iloc[i]['Name'])
    
players_list
# Out:
# ['Renato Augusto',
#  'C. Vela',
#  'D. Zapata',
#  'Rafa',
#  'M. Dúbravka',
#  'M. Acuña',
#  'Ronaldo Cabrais',
#  'João Moutinho',
#  'J. Vertonghen',
#  'D. Tadić',
#  'C. Aránguiz',
#  'W. Zaha',
#  'I. Gueye',
#  'Aitor',
#  'K. Manolas',
#  'L. Hrádecký',
#  'Douglas Costa',
#  'Muniain',
#  'Coutinho',
#  'K. Trapp',
#  'Oscar',
#  'Paulinho',
#  'I. Gündoğan',
#  'José Callejón',
#  'Azpilicueta',
#  'Fernando',
#  'Yuri Berchiche',
#  'A. Vidal',
#  'E. Džeko',
#  'R. Nainggolan',
#  'Marcelo',
#  'G. Bale',
#  'S. Mandanda',
#  'E. Banega',
#  'Portu',
#  'Sergi Roberto',
#  'F. Acerbi',
#  'Allan',
#  'Morata',
#  'T. Hazard',
#  'Jorginho',
#  'E. Višća',
#  'Gerard Moreno',
#  'F. Kostić',
#  'F. Thauvin',
#  'Raúl Albiol',
#  'T. Vaclík',
#  'G. Higuaín',
#  'I. Rakitić',
#  'N. Pope',
#  'D. Payet',
#  'A. Lacazette',
#  'Danilo Pereira',
#  'S. Berghuis',
#  'J. Rodríguez',
#  'Rodrigo',
#  'Neto',
#  'O. Baumann',
#  'Mário Fernandes',
#  'Sergio Asenjo',
#  'J. Cuadrado',
#  'D. Blind',
#  'Canales',
#  'A. Ramsey',
#  'K. Trippier',
#  'M. Arnautović',
#  'F. Muslera',
#  'I. Perišić',
#  'B. Matuidi',
#  'G. Buffon',
#  'Pau López',
#  'Lucas Moura',
#  'L. Ocampos',
#  'M. Ginter',
#  'Y. Carrasco',
#  'A. Marchesín',
#  'A. Kramarić',
#  'D. Djené',
#  'R. Gosens',
#  'Gabriel Paulista',
#  'Josué Chiamulera',
#  'Raphaelito Anjos',
#  'Nuno Padrenda',
#  'Oswaldinato',
#  'M. Politano',
#  'J. Pavlenka',
#  'J. Martínez',
#  'E. Salvio',
#  'K. Volland',
#  'Paco Alcácer',
#  'J. Cillessen',
#  'Campaña',
#  'Pablo Sarabia',
#  'Jonathan Viera',
#  'S. Coates',
#  'D. Ings',
#  'K. Kampl',
#  'T. Delaney',
#  'H. Mkhitaryan',
#  'M. Götze',
#  'Taison',
#  'Capa',
#  'Marlos',
#  'A. Kolarov',
#  'M. Kruse',
#  'Willian',
#  'S. Bender',
#  'L. Bender',
#  'M. Özil',
#  'Marcano',
#  'S. Mignolet',
#  'M. Hamšík',
#  'L. Fabiański',
#  'A. Consigli',
#  'Ismaily',
#  'M. Doherty',
#  'Felipe Anderson',
#  'Suso',
#  'I. Fernández',
#  'G. Rulli',
#  'M. Halstenberg',
#  'A. Rabiot',
#  'Fred',
#  'Q. Promes',
#  'M. de Roon',
#  'H. Çalhanoğlu',
#  'Louri Beretta',
#  'A. Plea',
#  'E. Andrada',
#  'A. Rüdiger',
#  'E. Zahavi',
#  'S. Arias',
#  'A. Florenzi',
#  'K. Bellarabi',
#  'Welington Dano',
#  'M. Lazzari',
#  'Rosberto Dourado',
#  'A. Gignac',
#  'H. Herrera',
#  'F. Ribéry',
#  'Adryan Zonta',
#  'Iniesta',
#  'W. Weghorst',
#  'Pepe',
#  'Juiano Mestres',
#  'M. Dmitrović',
#  'Luiz Gustavo',
#  'F. Coquelin',
#  'N. Nkoulou',
#  'L. Stindl',
#  'A. Sánchez',
#  'Giuliano',
#  'S. Giovinco',
#  'David Luiz',
#  'S. Khedira',
#  'Diego Costa',
#  'Adán',
#  'S. Kjær',
#  'M. Baldona',
#  'S. Mandíquez',
#  'J. Serendero',
#  'J. Sildero',
#  'J. Frendado',
#  'Nacho Monreal',
#  'S. Ardero',
#  'L. Dálves',
#  'M. Nérez',
#  'E. Schetino',
#  'Javi Martínez',
#  'Falcao',
#  'A. Robben',
#  'Lucas Vázquez',
#  'P. Zieliński',
#  'D. Berardi',
#  'Rubén Peña',
#  'K. Demirbay',
#  'P. Max',
#  'F. Bernardeschi',
#  'João Mário',
#  'Ricardo Horta',
#  'J. Evans',
#  'E. Lamela',
#  'Raúl García',
#  'E. Forsberg',
#  'William Carvalho',
#  'Joaquín',
#  'I. Akinfeev',
#  'B. Gomis',
#  'F. Quagliarella',
#  'M. Dembélé',
#  'S. Ruffier',
#  'Miranda',
#  'Iñigo Martínez',
#  'S. Haller',
#  'B. Davies',
#  'L. Shaw',
#  'Maikel Catarino',
#  'Héniton Pires',
#  'Laure Santeiro',
#  'Hulk',
#  'Pedro',
#  'Guaita',
#  'L. de Jong',
#  'Illarramendi',
#  'B. André',
#  'N. Matić',
#  'Escudero',
#  'Mario Gaspar',
#  'X. Shaqiri',
#  'D. Wass',
#  'F. Armani',
#  'C. Tolisso',
#  'S. Lainer',
#  'André Almeida',
#  'Willian José',
#  'E. Pérez',
#  'N. Lodeiro',
#  'P. Kadeřábek',
#  'D. Suárez',
#  'S. Vrsaljko',
#  'Pozuelo',
#  'Tony Abranjes',
#  'E. Mendy',
#  'W. Boly',
#  'J. Tarkowski',
#  'Nacho Fernández',
#  'G. Krychowiak',
#  'S. Aurier',
#  'Bartra',
#  'C. Bakambu',
#  'L. Muriel',
#  'Jordi Masip',
#  'B. Lecomte',
#  'J. Roussillon',
#  'J. Veretout',
#  'M. Hinteregger',
#  'J. Draxler',
#  'E. Dier',
#  'T. Meunier',
#  'Deulofeu',
#  'S. Romero',
#  'C. Coady',
#  'N. Guzmán',
#  'Juan Mata',
#  'O. Giroud',
#  'S. Coleman',
#  'Melvin Parrela',
#  'Gabri Prestão',
#  'Luimo Boas Santos',
#  'R. Malinovskyi',
#  'Éder',
#  'Ángel',
#  'M. Valbuena',
#  'N. Amrabat',
#  'Sidnei',
#  'V. Ćorluka',
#  'Quaresma',
#  'Pepe Reina',
#  'J. Milner',
#  'Nani',
#  'G. Ochoa',
#  'A. Mirante',
#  'B. Costil',
#  'B. Foster',
#  'L. Koscielny',
#  'Rafinha',
#  'D. Valeri',
#  'L. Piszczek',
#  'Pedro León',
#  'D. Ospina',
#  'M. Díaz',
#  'José Sá',
#  'A. Hamdallah',
#  'F. Fabra',
#  'M. Casco',
#  'A. Izzo',
#  'Dani García',
#  'Morales',
#  'Paulinho',
#  'H. Traoré',
#  'T. Bakayoko',
#  'M. Vecino',
#  'A. Rebić',
#  'H. Hateboer',
#  'Zaldúa',
#  'André Gomes',
#  'Júnior Moraes',
#  'E. Guichón',
#  'R. Di Leonardo',
#  'E. Riquero',
#  'L. Sáreda',
#  'D. Machís',
#  'Samu Castillejo',
#  'Rubén García',
#  'M. Sissoko',
#  'M. Parolo',
#  'D. Perotti',
#  'J. Rodríguez',
#  'R. Aguilar',
#  'Mata',
#  'A. Mena',
#  'M. Dabbur',
#  'R. Saïss',
#  'Gabriel',
#  'R. Fraser',
#  'M. Keane',
#  'Manu Trigueros',
#  'C. Stuani',
#  'T. Stepanenko',
#  'W. Orban',
#  'Borja Iglesias',
#  'Everton Andrão',
#  'Adnan Vidual',
#  'Ronaldo Esler',
#  'M. Marega',
#  'R. Ruidíaz',
#  'M. Arnold',
#  'A. Carrillo',
#  'A. Oxlade-Chamberlain',
#  'A. Delort',
#  'N. Gudelj',
#  'Álvaro',
#  'Marcos Alonso',
#  'Ai Kesen',
#  'F. Orellana',
#  'N. Otamendi',
#  'Ander Herrera',
#  'M. Antonio',
#  'C. Smalling',
#  'B. Mee',
#  'Iborra',
#  'G. Bonaventura',
#  'F. Caputo',
#  'Alex Teixeira',
#  'S. Nzonzi',
#  "Y. M'Vila",
#  'C. Wilson',
#  'Jaume Costa',
#  'M. Ryan',
#  'A. Mandi',
#  'L. Spinazzola',
#  'A. Schwolow',
#  'Fernando',
#  'João Pedro',
#  'S. Sané',
#  'G. Kondogbia',
#  'Rafinha',
#  'H. Vanaken',
#  'Ibai Gómez',
#  'M. Bizot',
#  'Danilo',
#  'Lucas Pérez',
#  'G. Xhaka',
#  'M. Sels',
#  'Vitolo',
#  'E. Hysaj',
#  'M. Suárez',
#  'L. Acosta',
#  'S. Lulić',
#  'M. Lanzini',
#  'B. Dost',
#  'A. Westwood',
#  'A. Cresswell',
#  'Rafael Carioca',
#  'Jorge Molina',
#  'M. Debuchy',
#  'D. Mbokani',
#  'I. Piatti',
#  'F. Caicedo',
#  'K. Boateng',
#  'C. Ansaldi',
#  'A. Candreva',
#  'D. Criscito',
#  'V. Moses',
#  'Sokratis',
#  'A. Guardado',
#  'José Fonte',
#  'Fábio Coentrão',
#  'Gervinho',
#  'R. Bertrand',
#  'M. Škrtel',
#  'Ș. Radu',
#  'K. Gameiro',
#  'E. Capoue',
#  'De Marcos',
#  'P. Diop',
#  'Moyá',
#  'B. Yılmaz',
#  'L. López',
#  'C. Tévez',
#  'J. Sosa',
#  'C. Kouyaté',
#  'S. Ulreich',
#  'M. Musacchio',
#  'S. Feghouli',
#  'L. Montes',
#  'G. Sigurðsson',
#  'P. Piatti',
#  'Víctor Díaz',
#  'Antunes',
#  'B. Ivanović',
#  'Cote',
#  'M. Hitz',
#  'R. Steffen',
#  'V. Coufal',
#  'D. Lenzado',
#  'E. Aguerro',
#  'S. Luna',
#  'J. Hofmann',
#  'De Tomás',
#  'J. Córdoba',
#  'F. Schär',
#  'J. Nsame',
#  'C. Günter',
#  'F. Mollet',
#  'Omar Mascarell',
#  'Clinton Mata',
#  'B. Cristante',
#  'Y. Poulsen',
#  'A. Doucouré',
#  'R. Olsen',
#  'F. Midtsjø',
#  'C. Tătărușanu',
#  'N. Schulz',
#  'N. Chadli',
#  'Cristian Tello',
#  'L. Dunk',
#  'N. Pallois',
#  'R. Barkley',
#  "D. D'Ambrosio",
#  'N. Redmond',
#  'J. Svensson',
#  'D. Demme',
#  'Germán',
#  'C. Ortiz',
#  'Sérgio Oliveira',
#  'A. Townsend',
#  'Laguardia',
#  'Y. El Arabi',
#  'R. Soriano',
#  'R. Rodríguez',
#  'R. Freuler',
#  'L. Vietto',
#  'Denis Suárez',
#  'L. Trossard',
#  'Roberto Torres',
#  'Moi Gómez',
#  'L. Milivojević',
#  'M. De Sciglio',
#  'Leo Baptistao',
#  'Z. Feddal',
#  'T. Savanier',
#  'F. Novák',
#  'T. Inui',
#  'J. Vestergaard',
#  'J. Egan',
#  'Mário Rui',
#  'J. Bořil',
#  'K. Lala',
#  'C. Kramer',
#  'K. Fortounis',
#  'D. Klaassen',
#  'M. Uribe',
#  'B. Verbič',
#  'Wu Lei',
#  'Petros',
#  'Jony',
#  'F. Cervi',
#  'A. Ljajić',
#  'J. Amavi',
#  'P. Lees-Melou',
#  'Gazzolisco',
#  'Wellington Sabrão',
#  'Antônio Chiamuloira',
#  'Vincente Dourado',
#  'Everticinho',
#  'Albertinho Dutra',
#  'Y. Mina',
#  'Arturo Inálcio',
#  'S. Kritsyuk',
#  'S. El Shaarawy',
#  'Maicon',
#  'L. Rodríguez',
#  'C. Wood',
#  'S. Mustafi',
#  'E. Stevens',
#  'Herrerín',
#  'V. Grifo',
#  'Ricardo Esgaio',
#  'R. De Paul',
#  'Sequeira',
#  'Puertas',
#  'Thiago Mendes',
#  'B. Bourigeaud',
#  'C. Izquierdoz',
#  'I. Marcone',
#  'D. Benedetto',
#  'L. Alario',
#  'Ayoze Pérez',
#  'D. Zappacosta',
#  'Marcelo Goiano',
#  'L. Dubois',
#  'Guilson Paiva',
#  'Fredditinho',
#  'Matheus Bardeira',
#  'Prazeracinho',
#  'M. Almirón',
#  'M. Silvestri',
#  'O. Al Soma',
#  'A. McCarthy',
#  'Alan Carvalho',
#  'Fábio Martins',
#  'H. Sakai',
#  'J. Lingard',
#  'J. Veltman',
#  'M. Pereyra',
#  'C. McGregor',
#  'X. Chavalerin',
#  'Soares',
#  'Zé Luís',
#  'Vieirundinho',
#  'A. Yarmolenko',
#  'Guilherme',
#  'J. Cork',
#  'J. Lerma',
#  'J. Guilavogui',
#  'J. Fuenzalida',
#  'Pedro Mendes',
#  'D. Praet',
#  'Victildinho',
#  'A. Taarabt',
#  'B. Sarr',
#  'Hugo Mallo',
#  'R. Haps',
#  'E. Rigoni',
#  'Rodrigo Vuarte',
#  'J. Hector',
#  'Rafael Tolói',
#  'C. Bravo',
#  'Oier',
#  'C. Basham',
#  'F. Ghoulam',
#  'Andrei Girotto',
#  'Bernard',
#  'Nacho',
#  'D. Boyata',
#  'D. Caligiuri',
#  'Wagner Laranjo',
#  'Jaume',
#  'S. Zaza',
#  'Víctor Ruiz',
#  'T. Heaton',
#  'Beñat',
#  'Andeson Trigo',
#  'Álex Moreno',
#  'Mariano',
#  'Rochina',
#  'Jadsinho Mei',
#  'Y. Belhanda',
#  'J. Shelvey',
#  'N. Stanciu',
#  'Rodrigo Vuarte',
#  'Sidney Pessinho',
#  'Vieirundinho',
#  'Victildinho',
#  'Jadsinho Mei',
#  'Andeson Trigo',
#  'Wagner Laranjo',
#  'Claudio Coíntra',
#  'Enzo Chissano',
#  'Alexo Baia',
#  'Lucas Mantela',
#  'A. Nwakaeme',
#  'Davidson',
#  'S. Nakajima',
#  'R. Vormer',
#  'M. Taremi',
#  'Rubén Alcaraz',
#  'Sergi Guardiola',
#  'Alberto Moreno',
#  'Soares',
#  'Andrei Girotto',
#  'M. Batshuayi',
#  'M. Elneny',
#  'G. Baldock',
#  'A. Gomis',
#  'J. Herrería',
#  'L. Baezo',
#  'F. Contedo',
#  'V. Castro',
#  'L. Biglia',
#  'Sergi Guardiola',
#  'J. Schmid',
#  'J. Fleck',
#  'B. Hübner',
#  'Otávio',
#  'R. Funes Mori',
#  'S. Romero',
#  'W. Cyprien',
#  'Oriol Romeu',
#  'Roger',
#  'A. Samaris',
#  'A. Nwakaeme',
#  'J. Palomino',
#  'Marcelo',
#  'F. Vázquez',
#  'Matheus',
#  'R. Rosales',
#  'Cláudio Ramos',
#  'S. Blanco',
#  'G. Cahill',
#  'C. Vargas',
#  'R. Babel',
#  'Andrés Fernández',
#  'K. Berlaso',
#  'J. dos Santos',
#  'K. Vogt',
#  'M. Uth',
#  'Claudio Coíntra',
#  'Miguel Veloso',
#  'J. Ayew',
#  'Pablo',
#  'A. Young',
#  'G. Kakuta',
#  'Montoya',
#  'A. Lallana',
#  'D. Sidibé',
#  'Davidson',
#  'P. van Aanholt',
#  'J. King',
#  'V. Castro',
#  'D. Da Silva',
#  'R. Gurtner',
#  'Y. Zhirkov',
#  'Soldado',
#  'K. Toko Ekambi',
#  'N. Kalinić',
#  'M. Gonalons',
#  'D. Baselli',
#  'Enzo Chissano',
#  'L. Bittencourt',
#  'D. Rose',
#  'M. Taremi',
#  'Hilton',
#  'N. Maksimović',
#  'D. Foulquier',
#  'Kike García',
#  'J. Baumgartlinger',
#  'Borja Valero',
#  'M. Günok',
#  'J. Murillo',
#  'D. Bouanga',
#  'S. Nakajima',
#  'M. Ozdoev',
#  'Y. Abdelhamid',
#  'Rubén Alcaraz',
#  'J. Kucka',
#  'L. Unnerstall',
#  'Sergi Gómez',
#  'S. Kolašinac',
#  'Sergi Darder',
#  'H. Moreno',
#  'A. Kokorin',
#  'D. González',
#  'Y. Chará',
#  'Dyego Sousa',
#  'C. Kabasele',
#  'Pedro Obiang',
#  'N. Füllkrug',
#  'E. Berisha',
#  'O. Ighalo',
#  'Aderllan Santos',
#  'A. Blake',
#  'O. Elabdellaoui',
#  'G. Rodríguez',
#  'T. Foket',
#  'L. Andersen',
#  'R. Thomas',
#  'Bruno Peres',
#  'G. Defrel',
#  'A. Ademi',
#  'M. Livaja',
#  'O. Norwood',
#  'David López',
#  'R. Fredericks',
#  'W. Rooney',
#  'D. Kuzyaev',
#  'Cesc Fàbregas',
#  'E. Mena',
#  'N. Gaitán',
#  'W. Khazri',
#  'N. Petersen',
#  'M. Schneiderlin',
#  'D. Le Tallec',
#  'R. Hamouma',
#  'C. Piccini',
#  'M. Borja',
#  'C. Taylor',
#  'J. Gouweleeuw',
#  'T. Gebre Selassie',
#  'G. Gönül',
#  'T. Krul',
#  'A. Mehmedi',
#  'M. Berg',
#  'J. McCarthy',
#  'S. Widmer',
#  'L. Sigali',
#  'H. Pérez',
#  'T. Cairney',
#  'R. Sambueza',
#  'I. Slimani',
#  'C. Erkin',
#  'F. Smolov',
#  'Raúl',
#  'J. Guðmundsson',
#  'Marçal',
#  'M. Albrighton',
#  'J. Boëtius',
#  'C. Clark',
#  'A. Hutchinson',
#  'A. Dzagoev',
#  'R. Falk',
#  'A. Poli',
#  'T. Deeney',
#  'Joel Robles',
#  'F. Delph',
#  'Pierrino Faria',
#  'M. Badelj',
#  'T. Hamed',
#  'J. Forrest',
#  'J. Farfán',
#  'O. Murillo',
#  'A. Ayew',
#  'M. Philipp',
#  'J. Lukaku',
#  'A. Budimir',
#  'Hernâni',
#  'Nelsildo Reis',
#  'O. Romero',
#  'Fred Aníbão',
#  'A. Romero',
#  'Júnior Caiçara',
#  'J. Willems',
#  'F. Niederlechner',
#  'P. Herrmann',
#  'I. Belfodil',
#  'N. Mendy',
#  'J. Pastore',
#  'Lafortiscinho',
#  'Gabriel',
#  'S. Andersson',
#  'Edgar Badía',
#  'O. Karnezis',
#  'D. da Costa',
#  'A. Romao',
#  'L. Augustinsson',
#  'R. Jarstein',
#  'J. Hart',
#  'V. Claesson',
#  'M. Kranevitter',
#  'D. Brašanac',
#  'K. Johnsson',
#  'J. Hansen',
#  'S. Deli',
#  'A. Thomasson',
#  'Wendell',
#  'D. Cheryshev',
#  'A. Mooy',
#  'A. Younes',
#  'Toni Villa',
#  'S. Ristovski',
#  'L. Chichizola',
#  'Y. Gómez Andrade',
#  'F. Tait',
#  'Nolito',
#  'Antonaldinho',
#  'F. Fazio',
#  'D. Pröpper',
#  'G. Trauner',
#  'A. Oukidja',
#  'Gonçalo Paciência',
#  'H. Martín',
#  'D. Stephens',
#  'A. Soumaoro',
#  'Kim Shin Wook',
#  'S. Klaiber',
#  'Kiko Femenía',
#  'P. Skjelbred',
#  'Fei Nanduo',
#  'Z. Junuzović',
#  'M. Gradel',
#  'Dante',
#  'O. Toprak',
#  'Tomás Pina',
#  'D. Lazović',
#  'Cédric',
#  'T. Pukki',
#  'D. Laxalt',
#  'J. Tavernier',
#  'Fran Mérida',
#  'Lúcio Corteijo',
#  'Sergi Enrich',
#  'A. Píriz',
#  'Simão Acunha',
#  'Diego Castro',
#  'Y. Bounou',
#  'Diego López',
#  'J. Zoet',
#  'Gabrisco Aníbal',
#  'Wilson Eduardo',
#  'Jason',
#  'E. Sviatchenko',
#  'M. Sportiello',
#  'G. Pizarro',
#  'S. Petrov',
#  'Adilson Edrada',
#  'M. Lemina',
#  'G. Martínez',
#  'M. Darmian',
#  'L. Rémy',
#  'F. Di Francesco',
#  'A. Pyatov',
#  'David Seijalbo',
#  'W. Endo',
#  'K. Malcuit',
#  'Garry Rodrigues',
#  'Adrián López',
#  'Adrien Silva',
#  'Y. Court',
#  'T. Walcott',
#  'G. Medel',
#  'Aleix Vidal',
#  'J. Gallardo',
#  'Diego Rico',
#  'Rômulo',
#  'J. Brooks',
#  'F. Rønnow',
#  'Z. Ferhat',
#  'M. Nastasić',
#  'J. Monsario',
#  'Joselu',
#  'J. Hernández',
#  'P. Groß',
#  'Silas Almeim',
#  'A. Zamorado',
#  'G. Castro',
#  'I. Traoré',
#  'Roque Mesa',
#  'M. Sakho',
#  'N. Domínguez',
#  'M. Oršić',
#  'Paulo Oliveira',
#  'N. Clyne',
#  'G. Cuéllar',
#  'Alan Kardec',
#  'Anselmo',
#  'A. Barnes',
#  'Rubem Esteiro',
#  'J. Ward',
#  'J. Furch',
#  'V. Odjidja-Ofoe',
#  'F. Acheampong',
#  'J. Pinola',
#  'A. Talavera',
#  'R. Boudebouz',
#  'Daniel Carriço',
#  'D. Abraham',
#  'J. Orozco',
#  'D. Siovas',
#  'Nicolás Filhei',
#  'L. Zelarayán',
#  'G. Clichy',
#  'J. Tomkins',
#  'B. Mechele',
#  'Óscar Plano',
#  'L. Fer',
#  'Souza',
#  'Rafael',
#  'Carles Gil',
#  'R. Knoche',
#  'G. Makaridze',
#  'K. Strootman',
#  'V. Wanyama',
#  'L. López',
#  'M. Braithwaite',
#  'Manuel Fernandes',
#  'Negredo',
#  'A. Smith',
#  'P. Olayinka',
#  'D. Randolph',
#  'J. Haberer',
#  'K. Lasagna',
#  'M. Pavlović',
#  'C. Cueva',
#  'Tiago Pinto',
#  'A. Ricaurte',
#  'J. Sánchez Miño',
#  'C. Tosun',
#  'K. Laba',
#  'Javi García',
#  'L. Quiñones',
#  'Danilo',
#  'N. Moumi Ngamaleu',
#  'Rodrigo',
#  'A. Adnan',
#  'F. Kainz',
#  'M. Cáceres',
#  'L. Janson',
#  'Zainadine',
#  'P. Hernández',
#  'J. Wallace',
#  'M. Pjaca',
#  'D. Burn',
#  'D. Quintero',
#  'Luo Guofu',
#  'P. Jones',
#  'C. Trimmel',
#  'A. Mierzejewski',
#  'M. Heča',
#  'M. Rits',
#  'V. Buyalskyi',
#  'V. Aboubakar',
#  'C. Fassnacht',
#  'G. Cabral',
#  'L. Júnior',
#  'B. Pittón',
#  'P. Onuachu',
#  'Cris Laranjeiros',
#  'R. Brady',
#  'A. Nyom',
#  'A. Masiello',
#  'O. Nguette',
#  'M. Borjan',
#  'P. Jansson',
#  'F. Klos',
#  'D. Heintz',
#  'S. Larsson',
#  'Nélson Oliveira',
#  'T. Vermaelen',
#  'Eraso',
#  'P. Tau',
#  'M. Quiroga',
#  'J. Toornstra',
#  'A. Donatti',
#  'F. Lustenberger',
#  'M. Meza',
#  'Formosandrinho',
#  'S. Lung',
#  'I. Pillud',
#  'S. Duffy',
#  'Postigo',
#  'L. Schøne',
#  'A. Christiansen',
#  'H. Ben Arfa',
#  'J. Dueñas',
#  'A. Epureanu',
#  'Roberto',
#  'Djaniny',
#  'F. Rinaudo',
#  'Filipe Augusto',
#  'P. Capelle',
#  'H. Rodallega',
#  'E. Pulgar',
#  'M. Eikrem',
#  'Rubens Freitosa',
#  'Jo Hyeon Woo',
#  'M. Lowton',
#  'K. Stöger',
#  'M. Samatta',
#  'Jesus Andradaldo',
#  'G. Herrera',
#  'L. Skorupski',
#  'Toño García',
#  'J. Rodríguez',
#  'A. Cornelius',
#  'S. Bahoken',
#  'B. Reynet',
#  'M. Rojo',
#  'Rafael Cachoira',
#  'H. Seferović',
#  'J. Seri',
#  'E. Bičakčić',
#  'A. Dragović',
#  'F. Balbuena',
#  'P. Pekarík',
#  'A. Hunou',
#  'Pablo Hernández',
#  'Kévin Rodrigues',
#  'L. Rodríguez',
#  'E. Balanta',
#  'D. Diekmeier',
#  'R. Palacio',
#  'Jailson Caeiro',
#  'Maurício',
#  'L. Podolski',
#  'M. Hasebe',
#  'M. Bíttolo',
#  'Jorginhson',
#  'J. Larsen',
#  'H. González',
#  ...]

# %% [markdown]
# ## chart

# %%
plt.figure(figsize = (18,8))
ax = sns.countplot('BestPosition', data =player_new)
ax.set_xlabel(xlabel = 'Different Positions in Football', fontsize = 16)
ax.set_ylabel(ylabel = 'Cont of Players', fontsize = 16)
ax.set_title(label = 'Comparsion of  Positions and Players', fontsize = 20)
plt.show()

# %% [markdown]
# ## players with future!!!

# %% [markdown]
# ### I define it with potential more than 85  and age under 23

# %%
import numpy as np
import matplotlib.pyplot as plt
#clubs 
clubs = players['Club'].unique()
good_future_dict = {}
for club in clubs:
    good_future_dict[club] = 0  
for i in range (players.shape[0]): 
    if players.iloc[i]['Potential']>=85 and players.iloc[i]['Age']<=23:
        good_future_dict[players.iloc[i]['Club']] += 1        
good_future_dict = sorted(good_future_dict.items(), key=lambda x: x[1], reverse=True)
height = [good_future_dict[0][1], good_future_dict[1][1], good_future_dict[2][1], good_future_dict[3][1], good_future_dict[4][1]]
bars = (good_future_dict[0][0], good_future_dict[1][0], good_future_dict[2][0], good_future_dict[3][0], good_future_dict[4][0])
# Create bars 
plt.bar(bars, height)
plt.xticks(rotation=45)
# Add title and axis names
plt.title('Top 5 clubs with the most players')
plt.xlabel('clubs')
plt.ylabel('numberof players')
# Out:
# Text(0, 0.5, 'numberof players')

# %% [markdown]
# ## players contract until 2021 and dont play in national team

# %%
players_until2021_noteam= []

for i  in range (players.shape[0]):
    if players.iloc[i]['ContractUntil'] == 2021 and  players.iloc[i]['NationalTeam'] == 'Not in team' :
            players_until2021_noteam.append(players.iloc[i]['Name'])
print("players are{}".format(players_until2021_noteam))
# Out:
# players are['L. Modrić', 'Fernandinho', 'Thiago Silva', 'J. Boateng', 'E. Cavani', 'Z. Ibrahimović', 'Jesús Navas', 'Renato Augusto', 'Douglas Costa', 'Juan Bernat', 'E. Višća', 'F. Thauvin', 'G. Higuaín', 'M. Perin', 'A. Areola', 'F. Muslera', 'B. Matuidi', 'G. Buffon', 'M. Politano', 'Angeliño', 'Jonathan Viera', 'Taison', 'Marlos', 'A. Kolarov', 'S. Bender', 'L. Bender', 'M. Özil', 'M. Hamšík', 'Felipe Anderson', 'S. Arias', 'L. Torreira', 'A. Gignac', 'F. Ribéry', 'Iniesta', 'M. Dmitrović', 'N. Nkoulou', 'L. Stindl', 'David Luiz', 'S. Khedira', 'Diego Costa', 'Nacho Monreal', 'Javi Martínez', 'A. Robben', 'Lucas Vázquez', 'Otávio', 'D. Rugani', 'João Mário', 'Raúl García', 'Joaquín', 'F. Quagliarella', 'M. Dembélé', 'S. Ruffier', 'Miranda', 'Guaita', 'Escudero', 'N. Lodeiro', 'Nacho Fernández', 'C. Bakambu', 'Deulofeu', 'S. Romero', 'N. Guzmán', 'Juan Mata', 'Éder', 'Ángel', 'M. Valbuena', 'N. Amrabat', 'V. Ćorluka', 'Nani', 'A. Mirante', 'D. Valeri', 'L. Piszczek', 'Pedro León', 'M. Díaz', 'Morales', 'T. Bakayoko', 'Júnior Moraes', 'Vinícius', 'M. Parolo', 'Mata', 'A. Mena', 'Dani Ceballos', 'R. Saïss', 'M. Marega', 'M. Antonio', 'B. Mee', 'Jaume Costa', 'A. Mandi', 'E. Hysaj', 'S. Lulić', 'M. Debuchy', 'D. Mbokani', 'K. Boateng', 'C. Ansaldi', 'A. Candreva', 'V. Moses', 'Sokratis', 'Fábio Coentrão', 'Gervinho', 'R. Bertrand', 'M. Škrtel', 'Ș. Radu', 'K. Gameiro', 'De Marcos', 'P. Diop', 'Moyá', 'L. López', 'C. Tévez', 'M. Musacchio', 'L. Montes', 'P. Piatti', 'B. Ivanović', 'M. Hitz', 'Emerson', 'A. Lafont', 'N. De la Cruz', 'R. Barkley', 'J. Svensson', 'Sérgio Oliveira', 'A. Townsend', 'Y. El Arabi', 'Roberto Torres', 'M. De Sciglio', 'Leo Baptistao', 'K. Lala', 'L. Karius', 'R. Borré', 'Jony', 'J. Amavi', 'Maicon', 'S. Mustafi', 'Herrerín', 'I. Marcone', 'D. Zappacosta', 'Marcelo Goiano', 'M. Silvestri', 'O. Al Soma', 'Fábio Martins', 'L. Olaza', 'J. Lingard', 'M. Pereyra', 'J. Cork', 'Pedro Mendes', 'E. Rigoni', 'S. Benrahma', 'M. Guendouzi', 'Oier', 'C. Basham', 'Rony Lopes', 'Víctor Ruiz', 'T. Heaton', 'Beñat', 'Rochina', 'Y. Belhanda', 'M. Guendouzi', 'L. Biglia', 'W. Cyprien', 'Marcelo', 'F. Vázquez', 'G. Cahill', 'Miguel Veloso', 'Pablo', 'A. Young', 'G. Kakuta', 'P. van Aanholt', 'D. Da Silva', 'Soldado', 'D. Rose', 'Pedro Henrique', 'Hilton', 'N. Maksimović', 'Kike García', 'Borja Valero', 'R. Loftus-Cheek', 'L. Unnerstall', 'Y. Chará', 'Dyego Sousa', 'C. Kabasele', 'O. Ighalo', 'Bruno Peres', 'M. Livaja', 'W. Rooney', 'Jorge', 'N. Gaitán', 'N. Petersen', 'R. Hamouma', 'C. Piccini', 'T. Gebre Selassie', 'J. Andersen', 'F. Müller', 'G. Gönül', 'L. Sigali', 'R. Sambueza', 'I. Slimani', 'C. Clark', 'A. Dzagoev', 'Kenedy', 'T. Deeney', 'A. Miranchuk', 'M. Meyer', 'I. Amadou', 'A. Ayew', 'J. Lukaku', 'A. Budimir', 'Hernâni', 'Júnior Caiçara', 'J. Willems', 'A. Romao', 'M. Wolf', 'L. Chichizola', 'Vallejo', 'F. Fazio', 'Gonçalo Paciência', 'A. Soumaoro', 'Kim Shin Wook', 'Kiko Femenía', 'Z. Junuzović', 'Dante', 'Tomás Pina', 'A. Ndiaye', 'D. Laxalt', 'Matheus Reis', 'Diego López', 'M. Sportiello', 'G. Pizarro', 'Diogo Dalot', 'M. Lemina', 'M. Darmian', 'F. Di Francesco', 'A. Pyatov', 'Adrián López', 'T. Walcott', 'Rômulo', 'C. Romero', 'F. Rønnow', 'F. Tomori', 'M. Sakho', 'N. Domínguez', 'Paulo Oliveira', 'Borja Mayoral', 'J. Ward', 'F. Acheampong', 'J. Pinola', 'B. Henrichs', 'Daniel Carriço', 'D. Abraham', 'A. Fulgini', 'K. Baldé', 'J. Tomkins', 'Souza', 'Negredo', 'A. Smith', 'A. Ricaurte', 'J. Sánchez Miño', 'A. Adnan', 'M. Grujić', 'Frederico Venâncio', 'J. Todibo', 'P. Hernández', 'J. Wallace', 'M. Pjaca', 'D. Quintero', 'G. Cabral', 'L. Júnior', 'Pablo Maffeo', 'J. Reine-Adélaïde', 'F. Klos', 'Ontiveros', 'I. Radu', 'Nélson Oliveira', 'A. Donatti', 'M. Meza', 'Postigo', 'L. Schøne', 'H. Ben Arfa', 'J. Dueñas', 'T. Kubo', 'A. Epureanu', 'F. Rinaudo', 'Filipe Augusto', 'P. Capelle', 'H. Rodallega', 'M. Lowton', 'M. Samatta', 'G. Herrera', 'M. Rojo', 'Riqui Puig', 'P. Pekarík', 'Kévin Rodrigues', 'L. Rodríguez', ...

# %%
## second approach
players_until2021= []
player_2021=players[players['ContractUntil'] == 2021]
player_noTeam2021=player_2021[player_2021['NationalTeam'] == 'Not in team']

for i  in range (player_noTeam2021.shape[0]):
    players_until2021.append(player_noTeam2021.iloc[i]['Name'])
    
print(players_until2021  )
# Out:
# ['L. Modrić', 'Fernandinho', 'Thiago Silva', 'J. Boateng', 'E. Cavani', 'Z. Ibrahimović', 'Jesús Navas', 'Renato Augusto', 'Douglas Costa', 'Juan Bernat', 'E. Višća', 'F. Thauvin', 'G. Higuaín', 'M. Perin', 'A. Areola', 'F. Muslera', 'B. Matuidi', 'G. Buffon', 'M. Politano', 'Angeliño', 'Jonathan Viera', 'Taison', 'Marlos', 'A. Kolarov', 'S. Bender', 'L. Bender', 'M. Özil', 'M. Hamšík', 'Felipe Anderson', 'S. Arias', 'L. Torreira', 'A. Gignac', 'F. Ribéry', 'Iniesta', 'M. Dmitrović', 'N. Nkoulou', 'L. Stindl', 'David Luiz', 'S. Khedira', 'Diego Costa', 'Nacho Monreal', 'Javi Martínez', 'A. Robben', 'Lucas Vázquez', 'Otávio', 'D. Rugani', 'João Mário', 'Raúl García', 'Joaquín', 'F. Quagliarella', 'M. Dembélé', 'S. Ruffier', 'Miranda', 'Guaita', 'Escudero', 'N. Lodeiro', 'Nacho Fernández', 'C. Bakambu', 'Deulofeu', 'S. Romero', 'N. Guzmán', 'Juan Mata', 'Éder', 'Ángel', 'M. Valbuena', 'N. Amrabat', 'V. Ćorluka', 'Nani', 'A. Mirante', 'D. Valeri', 'L. Piszczek', 'Pedro León', 'M. Díaz', 'Morales', 'T. Bakayoko', 'Júnior Moraes', 'Vinícius', 'M. Parolo', 'Mata', 'A. Mena', 'Dani Ceballos', 'R. Saïss', 'M. Marega', 'M. Antonio', 'B. Mee', 'Jaume Costa', 'A. Mandi', 'E. Hysaj', 'S. Lulić', 'M. Debuchy', 'D. Mbokani', 'K. Boateng', 'C. Ansaldi', 'A. Candreva', 'V. Moses', 'Sokratis', 'Fábio Coentrão', 'Gervinho', 'R. Bertrand', 'M. Škrtel', 'Ș. Radu', 'K. Gameiro', 'De Marcos', 'P. Diop', 'Moyá', 'L. López', 'C. Tévez', 'M. Musacchio', 'L. Montes', 'P. Piatti', 'B. Ivanović', 'M. Hitz', 'Emerson', 'A. Lafont', 'N. De la Cruz', 'R. Barkley', 'J. Svensson', 'Sérgio Oliveira', 'A. Townsend', 'Y. El Arabi', 'Roberto Torres', 'M. De Sciglio', 'Leo Baptistao', 'K. Lala', 'L. Karius', 'R. Borré', 'Jony', 'J. Amavi', 'Maicon', 'S. Mustafi', 'Herrerín', 'I. Marcone', 'D. Zappacosta', 'Marcelo Goiano', 'M. Silvestri', 'O. Al Soma', 'Fábio Martins', 'L. Olaza', 'J. Lingard', 'M. Pereyra', 'J. Cork', 'Pedro Mendes', 'E. Rigoni', 'S. Benrahma', 'M. Guendouzi', 'Oier', 'C. Basham', 'Rony Lopes', 'Víctor Ruiz', 'T. Heaton', 'Beñat', 'Rochina', 'Y. Belhanda', 'M. Guendouzi', 'L. Biglia', 'W. Cyprien', 'Marcelo', 'F. Vázquez', 'G. Cahill', 'Miguel Veloso', 'Pablo', 'A. Young', 'G. Kakuta', 'P. van Aanholt', 'D. Da Silva', 'Soldado', 'D. Rose', 'Pedro Henrique', 'Hilton', 'N. Maksimović', 'Kike García', 'Borja Valero', 'R. Loftus-Cheek', 'L. Unnerstall', 'Y. Chará', 'Dyego Sousa', 'C. Kabasele', 'O. Ighalo', 'Bruno Peres', 'M. Livaja', 'W. Rooney', 'Jorge', 'N. Gaitán', 'N. Petersen', 'R. Hamouma', 'C. Piccini', 'T. Gebre Selassie', 'J. Andersen', 'F. Müller', 'G. Gönül', 'L. Sigali', 'R. Sambueza', 'I. Slimani', 'C. Clark', 'A. Dzagoev', 'Kenedy', 'T. Deeney', 'A. Miranchuk', 'M. Meyer', 'I. Amadou', 'A. Ayew', 'J. Lukaku', 'A. Budimir', 'Hernâni', 'Júnior Caiçara', 'J. Willems', 'A. Romao', 'M. Wolf', 'L. Chichizola', 'Vallejo', 'F. Fazio', 'Gonçalo Paciência', 'A. Soumaoro', 'Kim Shin Wook', 'Kiko Femenía', 'Z. Junuzović', 'Dante', 'Tomás Pina', 'A. Ndiaye', 'D. Laxalt', 'Matheus Reis', 'Diego López', 'M. Sportiello', 'G. Pizarro', 'Diogo Dalot', 'M. Lemina', 'M. Darmian', 'F. Di Francesco', 'A. Pyatov', 'Adrián López', 'T. Walcott', 'Rômulo', 'C. Romero', 'F. Rønnow', 'F. Tomori', 'M. Sakho', 'N. Domínguez', 'Paulo Oliveira', 'Borja Mayoral', 'J. Ward', 'F. Acheampong', 'J. Pinola', 'B. Henrichs', 'Daniel Carriço', 'D. Abraham', 'A. Fulgini', 'K. Baldé', 'J. Tomkins', 'Souza', 'Negredo', 'A. Smith', 'A. Ricaurte', 'J. Sánchez Miño', 'A. Adnan', 'M. Grujić', 'Frederico Venâncio', 'J. Todibo', 'P. Hernández', 'J. Wallace', 'M. Pjaca', 'D. Quintero', 'G. Cabral', 'L. Júnior', 'Pablo Maffeo', 'J. Reine-Adélaïde', 'F. Klos', 'Ontiveros', 'I. Radu', 'Nélson Oliveira', 'A. Donatti', 'M. Meza', 'Postigo', 'L. Schøne', 'H. Ben Arfa', 'J. Dueñas', 'T. Kubo', 'A. Epureanu', 'F. Rinaudo', 'Filipe Augusto', 'P. Capelle', 'H. Rodallega', 'M. Lowton', 'M. Samatta', 'G. Herrera', 'M. Rojo', 'Riqui Puig', 'P. Pekarík', 'Kévin Rodrigues', 'L. Rodríguez', 'Rodrigo E ...

# %% [markdown]
# ## value of chelsea players who are under 24

# %%
chelsea_under24 = {}
for i  in range (players.shape[0]):
    if  players.iloc[i]['Club'] == 'Chelsea' and  players.iloc[i]['Age'] < 24 :
        chelsea_under24[players.iloc[i]['Name']] = players.iloc[i]['ValueEUR']
print("chelsea players under 24 with their value {}".format(chelsea_under24))
# Out:
# chelsea players under 24 with their value {'K. Havertz': 121000000, 'B. Chilwell': 34500000, 'C. Pulisic': 41500000, 'M. Mount': 43000000, 'R. James': 29500000, 'T. Abraham': 29000000, 'F. Tomori': 15500000, 'C. Hudson-Odoi': 10000000, 'C. Musonda': 4800000, 'B. Gilmour': 4400000, 'D. Sterling': 2300000, 'J. Wakely': 500000}

# %% [markdown]
# ## Eden Hazard club salary position

# %%
for i in range(players.shape[0]):
    if players.iloc[i]['Name'] == 'E. Hazard':
        club = players.iloc[i]['Club']
        pos = players.iloc[i]['Positions']
        wage = players.iloc[i]['WageEUR']
print("Eden Hazard is playing in {} club with {} wage and {} positions".format(club,wage,pos))
# Out:
# Eden Hazard is playing in Real Madrid club with 350000 wage and LW positions
